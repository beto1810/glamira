# %%
from bs4 import BeautifulSoup # type: ignore # type: ignore
from time import sleep
import csv
import json
import pandas as pd # type: ignore
import re
import random
import requests # type: ignore
import urllib.request
from xml.etree import ElementTree as ET
from urllib.parse import urlparse
from urllib.parse import urlencode
import concurrent.futures
import os
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
import os
import requests
import re
import json
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import urllib.parse
import random
import concurrent.futures
import xml.etree.ElementTree as ET
import time

total_image = 0  # Global variable to count total images downloaded

products_dict = {}

def extract_key(url):
    parsed_url = urlparse(url)
    path_components = parsed_url.path.strip("/").split("/")
    return path_components[0]

def sanitize_file_name(text):
    text = text.replace(" ", "-")
    text = re.sub(r'[^A-Za-z0-9_-]', '', text)
    return text

def download_image(image_link, product_id, hash_product_name, view_number,param):
    global total_image  # Declare total_image as global to modify it
    
    folder = '/Users/dai/Documents/Data_Engineer/DE_K9_demo/Glamira_photo/photo'
    file_name = f"image_{product_id}_{hash_product_name}_{param}_{view_number}"
    file_path = os.path.join(folder, file_name)
    
    resp = requests.get(image_link)
    
    if resp.status_code == 200:
        with open(f"{file_path}.jpg", 'wb') as file:
            file.write(resp.content)
        
        total_image += 1  # Increment total_image
        print(f"Total images downloaded: {total_image}")
        
        #Every 25 links image, sleep 3-5 seconds
        if total_image % 25 == 0:
            print("Sleeping for 3-5 seconds...")
            time.sleep(random.uniform(3, 5))
    
    else:
        print(f"Failed to retrieve the image {image_link}")

    return file_path

def generate_image(image_first_link, product_id, hash_product_name,param):
    parts = image_first_link.split('/view/')
    base_url_part1 = parts[0] + '/view/'
    base_url_part2 = parts[1].split('/', 1)[1]
    
    image_download_paths = []
    
    for view_number in range(1, 5):
        image_view_link = f"{base_url_part1}{view_number}/{base_url_part2}"
        image_download = download_image(image_view_link, product_id, hash_product_name, view_number,param)
        image_download_paths.append(image_download)

    return image_download_paths

def take_product_info(soup, products_dict):
    product_items = soup.find_all('li', class_=['item', 'product', 'product-item'])

    for item in product_items:
        try:
            category_label = item.find('p', class_='enable-popover popover_stone_info')['data-ajax-data']
            category_json = json.loads(category_label)
            category_id = category_json['data_filter']['id']
        except:
            category_id = "No Found Category ID"

        try:
            product_id = item.find('div', class_='price-box price-final_price')['data-product-id']
        except:
            product_id = "No Found Product ID"

        try:
            product_name = item.find('h2', class_="product-name").get_text()
            hash_product_name = sanitize_file_name(product_name)
        except:
            product_name = "No Found Product Name"

        try:
            image_link = item.find('img')['srcset'].split(',')[0].split()[0]
            image_path = generate_image(image_link, product_id, hash_product_name)
        except:
            image_path = "No found images"
            
        try:
            product_link = item.find('a', class_='product-link')['href']
            param = item.find('a', class_='product-link')['data-param']
            param_dict = json.loads(param)
            json_str = urllib.parse.urlencode(param_dict)
            product_full_link = product_link + '?' + json_str
        except:
            product_link = "No Found Product Link"

        try:
            short_description = item.find('span', class_='short-description').get_text(strip=True)
        except:
            short_description = "No Found Short Description"

        try:
            carat_info = item.find('span', class_='carat').get_text(strip=True)
        except:
            carat_info = "No Found Carat Info"

        try:
            price = item.find('span', class_='price').get_text(strip=True)
        except:
            price = "No Found Price "

        try:
            product_info = json.loads(item.find('a', class_='product-link')['data-param'])
        except:
            product_info = "No Found Details"

        try:
            image_link = item.find('img')['srcset'].split(',')[0].split()[0]
            image_path = generate_image(image_link, product_id, hash_product_name,json_str)
        except:
            image_path = "No found images"

        product_details = {
            "Product Name": product_name,
            "Product ID": product_id,
            'Product Full Link': product_full_link,
            "Category ID": category_id,
            'Price': price,
            'Carat': carat_info,
            "Detail": product_info,
            "Descript": short_description,
            'Product Image Path': image_path
        }

        if product_name not in products_dict:
            products_dict[product_name] = {short_description: product_details}
        else:
            products_dict[product_name][short_description] = product_details

def get_api_links(link_category):
    
    api_link = link_category + "?isAjax=true&sections=list_product"
    
    print(link_category)

    try:
        session = requests.Session()
        retry_strategy = requests.packages.urllib3.util.retry.Retry(
            total=3,  # Number of retries
            status_forcelist=[429, 500, 502, 503, 504],  # HTTP statuses to retry on
            allowed_methods=["HEAD", "GET", "OPTIONS"],  # Methods to retry
            backoff_factor=random.uniform(0, 10)  # Retry delay in seconds
        )
        adapter = requests.adapters.HTTPAdapter(max_retries=retry_strategy)
        session.mount("https://", adapter)
        session.mount("http://", adapter)

        api_response = session.get(api_link, timeout=10)
        api_response.raise_for_status()  # Raise HTTPError for bad responses 

        if api_response.status_code == 200:
            api_content = api_response.content
            data = json.loads(api_content)
            html_content = data["list_product"]
            soup = BeautifulSoup(html_content, 'html.parser')
            take_product_info(soup, products_dict)
            last_page = int(soup.find('li', class_=['item', 'product', 'product-item'])['data-lastpage'])
            
            if last_page == 1:
                pass
            
            for i in range(2, last_page + 1):
                api_link_2 = f"{link_category}?p={i}&isAjax=true&sections=list_product"
                api_response = requests.get(api_link_2)
                api_content = api_response.content
                data = json.loads(api_content)
                html_content = data["list_product"]
                soup = BeautifulSoup(html_content, 'html.parser')
                take_product_info(soup, products_dict)

            # Save products_dict to JSON file
            output_file = 'category_details.json'
            with open(output_file, 'w', encoding='utf-8') as f:
                json.dump(products_dict, f, ensure_ascii=False, indent=4)

            print(f"{link_category} details saved to {output_file}")
            return products_dict

        else:
            print(f"Failed to fetch data from {api_link}. Status code: {api_response.status_code}")
            return {}

    except requests.RequestException as e:
        print(f"Error fetching initial data for {link_category}: {e}")
        return {}


# List of XML files containing API links
xml_files = [
    'https://www.glamira.com/media/sitemap/glus/category_filter_provider-41-2.xml'
]

links = []

# Extract all https links from XML files
for xml_file in xml_files:
    response = requests.get(xml_file)
    xml_content = response.content
    root = ET.fromstring(xml_content)

    for element in root.iter():
        if element.text is not None and element.text.startswith("https:") and "carat" not in element.text:
            links.append(element.text)



# Process API links with thread method
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(get_api_links, link) for link in links[800:850]]

    for future in concurrent.futures.as_completed(futures):
        result = future.result()
        if result:
            print("Image Download Counts per link_category:")
            print(f"Total images downloaded: {total_image}")
# Out:
# https://www.glamira.com/hand-of-hamsa-collection-earrings/green-sapphire/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/green-diamond/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/green-tourmaline/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/lab-grown-diamond/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/labdiamond/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/orange-sapphire/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/peridot/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/pink-tourmaline/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/pink-sapphire/
# https://www.glamira.com/hand-of-hamsa-collection-earrings/rhodolite-garnet/
# Total images downloaded: 1
# Total images downloaded: 2
# Total images downloaded: 3
# Total images downloaded: 4
# Total images downloaded: 5
# Total images downloaded: 6
# Total images downloaded: 7
# Total images downloaded: 8
# Total images downloaded: 9
# Total images downloaded: 10
# Total images downloaded: 11
# Total images downloaded: 12
# Total images downloaded: 13
# Total images downloaded: 14
# Total images downloaded: 15
# Total images downloaded: 16
# Total images downloaded: 17
# Total images downloaded: 18
# Total images downloaded: 19
# Total images downloaded: 20
# Total images downloaded: 21
# Total images downloaded: 22
# Total images downloaded: 23
# Total images downloaded: 24
# Total images downloaded: 25
# Sleeping for 3-5 seconds...
# Total images downloaded: 26
# Total images downloaded: 27
# Total images downloaded: 28
# Total images downloaded: 29
# Total images downloaded: 30
# Total images downloaded: 31
# Total images downloaded: 32
# Total images downloaded: 33
# Total images downloaded: 34
# Total images downloaded: 35
# Total images downloaded: 36
# Total images downloaded: 37
# Total images downloaded: 38
# Total images downloaded: 39
# Total images downloaded: 40
# Total images downloaded: 41
# Total images downloaded: 42
# Total images downloaded: 43
# Total images downloaded: 44
# Total images downloaded: 45
# Total images downloaded: 46
# Total images downloaded: 47
# Total images downloaded: 48
# Total images downloaded: 49
# Total images downloaded: 50
# Sleeping for 3-5 seconds...
# Total images downloaded: 51
# Total images downloaded: 52
# Total images downloaded: 53
# Total images downloaded: 54
# Total images downloaded: 55
# Total images downloaded: 56
# https://www.glamira.com/hand-of-hamsa-collection-earrings/rose-quartz/
# Image Download Counts per link_category:
# Total images downloaded: 56
# Total images downloaded: 57
# Total images downloaded: 58
# Total images downloaded: 59
# Total images downloaded: 60
# Total images downloaded: 61
# Total images downloaded: 62
# Total images downloaded: 63
# Total images downloaded: 64
# Total images downloaded: 65
# Total images downloaded: 66
# Total images downloaded: 67
# Total images downloaded: 68
# Total images downloaded: 69
# https://www.glamira.com/hand-of-hamsa-collection-earrings/ruby/
# Image Download Counts per link_category:
# Total images downloaded: 69
# Total images downloaded: 70
# Total images downloaded: 71
# Total images downloaded: 72
# Total images downloaded: 73
# Total images downloaded: 74
# Total images downloaded: 75
# Sleeping for 3-5 seconds...
# Total images downloaded: 76
# Total images downloaded: 77
# Total images downloaded: 78
# Total images downloaded: 79
# https://www.glamira.com/hand-of-hamsa-collection-earrings/swarovski-red/
# Image Download Counts per link_category:
# Total images downloaded: 79
# Total images downloaded: 80
# Total images downloaded: 81
# Total images downloaded: 82
# Total images downloaded: 83
# Total images downloaded: 84
# Total images downloaded: 85
# Total images downloaded: 86
# Total images downloaded: 87
# Total images downloaded: 88
# Total images downloaded: 89
# Total images downloaded: 90
# Total images downloaded: 91
# Total images downloaded: 92
# Total images downloaded: 93
# Total images downloaded: 94
# Total images downloaded: 95
# Total images downloaded: 96
# Total images downloaded: 97
# Total images downloaded: 98
# Total images downloaded: 99
# Total images downloaded: 100
# Sleeping for 3-5 seconds...
# Total images downloaded: 101
# Total images downloaded: 102
# Total images downloaded: 103
# Total images downloaded: 104
# Total images downloaded: 105
# Total images downloaded: 106
# Total images downloaded: 107
# Total images downloaded: 108
# Total images downloaded: 109
# Total images downloaded: 110
# Total images downloaded: 111
# Total images downloaded: 112
# Total images downloaded: 113
# Total images downloaded: 114
# Total images downloaded: 115
# Total images downloaded: 116
# Total images downloaded: 117
# Total images downloaded: 118
# Total images downloaded: 119
# Total images downloaded: 120
# Total images downloaded: 121
# Total images downloaded: 122
# Total images downloaded: 123
# Total images downloaded: 124
# Total images downloaded: 125
# Sleeping for 3-5 seconds...
# Total images downloaded: 126
# Total images downloaded: 127
# Total images downloaded: 128
# Total images downloaded: 129
# Total images downloaded: 130
# Total images downloaded: 131
# Total images downloaded: 132
# Total images downloaded: 133
# Total images downloaded: 134
# Total images downloaded: 135
# Total images downloaded: 136
# Total images downloaded: 137
# Total images downloaded: 138
# Total images downloaded: 139
# Total images downloaded: 140
# Total images downloaded: 141
# Total images downloaded: 142
# Total images downloaded: 143
# Total images downloaded: 144
# Total images downloaded: 145
# Total images downloaded: 146
# Total images downloaded: 147
# Total images downloaded: 148
# Total images downloaded: 149
# Total images downloaded: 150
# Sleeping for 3-5 seconds...
# Total images downloaded: 151
# Total images downloaded: 152
# Total images downloaded: 153
# Total images downloaded: 154
# Total images downloaded: 155
# Total images downloaded: 156
# Total images downloaded: 157
# Total images downloaded: 158
# Total images downloaded: 159
# Total images downloaded: 160
# Total images downloaded: 161
# Total images downloaded: 162
# Total images downloaded: 163
# Total images downloaded: 164
# Total images downloaded: 165
# Total images downloaded: 166
# Total images downloaded: 167
# Total images downloaded: 168
# Total images downloaded: 169
# Total images downloaded: 170
# Total images downloaded: 171
# Total images downloaded: 172
# Total images downloaded: 173
# Total images downloaded: 174
# Total images downloaded: 175
# Sleeping for 3-5 seconds...
# Total images downloaded: 176
# Total images downloaded: 177
# Total images downloaded: 178
# Total images downloaded: 179
# Total images downloaded: 180
# Total images downloaded: 181
# Total images downloaded: 182
# Total images downloaded: 183
# Total images downloaded: 184
# Total images downloaded: 185
# Total images downloaded: 186
# Total images downloaded: 187
# Total images downloaded: 188
# Total images downloaded: 189
# Total images downloaded: 190
# Total images downloaded: 191
# Total images downloaded: 192
# Total images downloaded: 193
# Total images downloaded: 194
# https://www.glamira.com/hand-of-hamsa-collection-earrings/sapphire/
# Image Download Counts per link_category:
# Total images downloaded: 194
# Total images downloaded: 195
# Total images downloaded: 196
# Total images downloaded: 197
# Total images downloaded: 198
# Total images downloaded: 199
# Total images downloaded: 200
# Sleeping for 3-5 seconds...
# Total images downloaded: 201
# Total images downloaded: 202
# Total images downloaded: 203
# Total images downloaded: 204
# Total images downloaded: 205
# Total images downloaded: 206
# Total images downloaded: 207
# Total images downloaded: 208
# Total images downloaded: 209
# Total images downloaded: 210
# Total images downloaded: 211
# Total images downloaded: 212
# Total images downloaded: 213
# Total images downloaded: 214
# Total images downloaded: 215
# Total images downloaded: 216
# Total images downloaded: 217
# Total images downloaded: 218
# Total images downloaded: 219
# Total images downloaded: 220
# Total images downloaded: 221
# Total images downloaded: 222
# Total images downloaded: 223
# Total images downloaded: 224
# Total images downloaded: 225
# Sleeping for 3-5 seconds...
# Total images downloaded: 226
# Total images downloaded: 227
# Total images downloaded: 228
# Total images downloaded: 229
# Total images downloaded: 230
# Total images downloaded: 231
# Total images downloaded: 232
# Total images downloaded: 233
# Total images downloaded: 234
# Total images downloaded: 235
# Total images downloaded: 236
# Total images downloaded: 237
# Total images downloaded: 238
# Total images downloaded: 239
# Total images downloaded: 240
# Total images downloaded: 241
# Total images downloaded: 242
# Total images downloaded: 243
# Total images downloaded: 244
# Total images downloaded: 245
# Total images downloaded: 246
# Total images downloaded: 247
# Total images downloaded: 248
# Total images downloaded: 249
# Total images downloaded: 250
# Sleeping for 3-5 seconds...
# Total images downloaded: 251
# Total images downloaded: 252
# Total images downloaded: 253
# Total images downloaded: 254
# Total images downloaded: 255
# Total images downloaded: 256
# Total images downloaded: 257
# Total images downloaded: 258
# Total images downloaded: 259
# Total images downloaded: 260
# Total images downloaded: 261
# Total images downloaded: 262
# Total images downloaded: 263
# Total images downloaded: 264
# Total images downloaded: 265
# Total images downloaded: 266
# Total images downloaded: 267
# Total images downloaded: 268
# Total images downloaded: 269
# Total images downloaded: 270
# Total images downloaded: 271
# Total images downloaded: 272
# Total images downloaded: 273
# Total images downloaded: 274
# Total images downloaded: 275
# Sleeping for 3-5 seconds...
# Total images downloaded: 276
# Total images downloaded: 277
# Total images downloaded: 278
# Total images downloaded: 279
# Total images downloaded: 280
# Total images downloaded: 281
# Total images downloaded: 282
# Total images downloaded: 283
# Total images downloaded: 284
# Total images downloaded: 285
# Total images downloaded: 286
# Total images downloaded: 287
# Total images downloaded: 288
# Total images downloaded: 289
# Total images downloaded: 290
# Total images downloaded: 291
# Total images downloaded: 292
# Total images downloaded: 293
# Total images downloaded: 294
# Total images downloaded: 295
# Total images downloaded: 296
# Total images downloaded: 297
# Total images downloaded: 298
# Total images downloaded: 299
# Total images downloaded: 300
# Sleeping for 3-5 seconds...
# Total images downloaded: 301
# Total images downloaded: 302
# Total images downloaded: 303
# Total images downloaded: 304
# Total images downloaded: 305
# Total images downloaded: 306
# Total images downloaded: 307
# Total images downloaded: 308
# Total images downloaded: 309
# Total images downloaded: 310
# Total images downloaded: 311
# Total images downloaded: 312
# Total images downloaded: 313
# Total images downloaded: 314
# Total images downloaded: 315
# Total images downloaded: 316
# Total images downloaded: 317
# Total images downloaded: 318
# Total images downloaded: 319
# Total images downloaded: 320
# Total images downloaded: 321
# Total images downloaded: 322
# Total images downloaded: 323
# Total images downloaded: 324
# Total images downloaded: 325
# Sleeping for 3-5 seconds...
# Total images downloaded: 326
# Total images downloaded: 327
# Total images downloaded: 328
# Total images downloaded: 329
# Total images downloaded: 330
# Total images downloaded: 331
# Total images downloaded: 332
# Total images downloaded: 333
# Total images downloaded: 334
# Total images downloaded: 335
# Total images downloaded: 336
# Total images downloaded: 337
# Total images downloaded: 338
# Total images downloaded: 339
# Total images downloaded: 340
# Total images downloaded: 341
# Total images downloaded: 342
# Total images downloaded: 343
# Total images downloaded: 344
# Total images downloaded: 345
# Total images downloaded: 346
# Total images downloaded: 347
# https://www.glamira.com/hand-of-hamsa-collection-earrings/swarovski-blue/
# Image Download Counts per link_category:
# Total images downloaded: 347
# Total images downloaded: 348
# Total images downloaded: 349
# Total images downloaded: 350
# Sleeping for 3-5 seconds...
# Total images downloaded: 351
# Total images downloaded: 352
# Total images downloaded: 353
# Total images downloaded: 354
# Total images downloaded: 355
# Total images downloaded: 356
# Total images downloaded: 357
# Total images downloaded: 358
# Total images downloaded: 359
# Total images downloaded: 360
# Total images downloaded: 361
# Total images downloaded: 362
# Total images downloaded: 363
# Total images downloaded: 364
# Total images downloaded: 365
# Total images downloaded: 366
# Total images downloaded: 367
# Total images downloaded: 368
# Total images downloaded: 369
# Total images downloaded: 370
# Total images downloaded: 371
# Total images downloaded: 372
# Total images downloaded: 373
# Total images downloaded: 374
# Total images downloaded: 375
# Sleeping for 3-5 seconds...
# Total images downloaded: 376
# Total images downloaded: 377
# Total images downloaded: 378
# Total images downloaded: 379
# Total images downloaded: 380
# Total images downloaded: 381
# Total images downloaded: 382
# Total images downloaded: 383
# Total images downloaded: 384
# Total images downloaded: 385
# Total images downloaded: 386
# Total images downloaded: 387
# Total images downloaded: 388
# Total images downloaded: 389
# Total images downloaded: 390
# Total images downloaded: 391
# Total images downloaded: 392
# Total images downloaded: 393
# Total images downloaded: 394
# Total images downloaded: 395
# Total images downloaded: 396
# Total images downloaded: 397
# https://www.glamira.com/hand-of-hamsa-collection-earrings/smoky-quartz/
# Image Download Counts per link_category:
# Total images downloaded: 397
# Total images downloaded: 398
# Total images downloaded: 399
# Total images downloaded: 400
# Sleeping for 3-5 seconds...
# Total images downloaded: 401
# Total images downloaded: 402
# Total images downloaded: 403
# Total images downloaded: 404
# Total images downloaded: 405
# Total images downloaded: 406
# Total images downloaded: 407
# Total images downloaded: 408
# Total images downloaded: 409
# Total images downloaded: 410
# Total images downloaded: 411
# Total images downloaded: 412
# Total images downloaded: 413
# Total images downloaded: 414
# Total images downloaded: 415
# Total images downloaded: 416
# Total images downloaded: 417
# Total images downloaded: 418
# Total images downloaded: 419
# Total images downloaded: 420
# Total images downloaded: 421
# Total images downloaded: 422
# Total images downloaded: 423
# Total images downloaded: 424
# Total images downloaded: 425
# Sleeping for 3-5 seconds...
# Total images downloaded: 426
# Total images downloaded: 427
# Total images downloaded: 428
# Total images downloaded: 429
# Total images downloaded: 430
# Total images downloaded: 431
# Total images downloaded: 432
# Total images downloaded: 433
# Total images downloaded: 434
# Total images downloaded: 435
# Total images downloaded: 436
# Total images downloaded: 437
# Total images downloaded: 438
# Total images downloaded: 439
# Total images downloaded: 440
# Total images downloaded: 441
# Total images downloaded: 442
# Total images downloaded: 443
# Total images downloaded: 444
# Total images downloaded: 445
# Total images downloaded: 446
# Total images downloaded: 447
# Total images downloaded: 448
# Total images downloaded: 449
# Total images downloaded: 450
# Sleeping for 3-5 seconds...
# Total images downloaded: 451
# Total images downloaded: 452
# Total images downloaded: 453
# Total images downloaded: 454
# Total images downloaded: 455
# Total images downloaded: 456
# Total images downloaded: 457Total images downloaded: 458
#
# Total images downloaded: 459
# Total images downloaded: 460
# Total images downloaded: 461
# Total images downloaded: 462
# Total images downloaded: 463
# Total images downloaded: 464
# Total images downloaded: 465
# Total images downloaded: 466
# Total images downloaded: 467
# Total images downloaded: 468
# Total images downloaded: 469
# Total images downloaded: 470
# Total images downloaded: 471
# Total images downloaded: 472
# Total images downloaded: 473
# Total images downloaded: 474
# Total images downloaded: 475
# Sleeping for 3-5 seconds...
# Total images downloaded: 476
# Total images downloaded: 477
# Total images downloaded: 478
# Total images downloaded: 479
# Total images downloaded: 480
# Total images downloaded: 481
# Total images downloaded: 482
# Total images downloaded: 483
# Total images downloaded: 484
# Total images downloaded: 485
# Total images downloaded: 486
# Total images downloaded: 487
# Total images downloaded: 488
# Total images downloaded: 489
# Total images downloaded: 490
# Total images downloaded: 491
# Total images downloaded: 492
# Total images downloaded: 493
# Total images downloaded: 494
# Total images downloaded: 495
# Total images downloaded: 496
# Total images downloaded: 497
# Total images downloaded: 498
# Total images downloaded: 499
# Total images downloaded: 500
# Sleeping for 3-5 seconds...
# Total images downloaded: 501
# Total images downloaded: 502
# Total images downloaded: 503
# Total images downloaded: 504
# Total images downloaded: 505
# Total images downloaded: 506
# Total images downloaded: 507
# Total images downloaded: 508
# Total images downloaded: 509
# Total images downloaded: 510
# Total images downloaded: 511
# Total images downloaded: 512
# Total images downloaded: 513
# Total images downloaded: 514
# Total images downloaded: 515
# Total images downloaded: 516
# Total images downloaded: 517
# Total images downloaded: 518
# Total images downloaded: 519
# Total images downloaded: 520
# Total images downloaded: 521
# Total images downloaded: 522
# Total images downloaded: 523
# Total images downloaded: 524
# Total images downloaded: 525
# Sleeping for 3-5 seconds...
# Total images downloaded: 526
# Total images downloaded: 527
# Total images downloaded: 528
# Total images downloaded: 529
# Total images downloaded: 530
# Total images downloaded: 531
# Total images downloaded: 532
# Total images downloaded: 533
# Total images downloaded: 534
# Total images downloaded: 535
# Total images downloaded: 536
# Total images downloaded: 537
# Total images downloaded: 538
# Total images downloaded: 539
# Total images downloaded: 540
# Total images downloaded: 541
# Total images downloaded: 542
# Total images downloaded: 543
# Total images downloaded: 544
# Total images downloaded: 545
# Total images downloaded: 546
# Total images downloaded: 547
# Total images downloaded: 548
# Total images downloaded: 549
# Total images downloaded: 550
# Sleeping for 3-5 seconds...
# Total images downloaded: 551
# Total images downloaded: 552
# Total images downloaded: 553
# Total images downloaded: 554
# Total images downloaded: 555
# Total images downloaded: 556
# Total images downloaded: 557
# Total images downloaded: 558
# Total images downloaded: 559
# Total images downloaded: 560
# Total images downloaded: 561
# Total images downloaded: 562
# Total images downloaded: 563
# Total images downloaded: 564
# Total images downloaded: 565
# Total images downloaded: 566
# Total images downloaded: 567
# Total images downloaded: 568
# Total images downloaded: 569
# Total images downloaded: 570
# Total images downloaded: 571
# Total images downloaded: 572
# Total images downloaded: 573
# Total images downloaded: 574
# Total images downloaded: 575
# Sleeping for 3-5 seconds...
# Total images downloaded: 576
# Total images downloaded: 577
# Total images downloaded: 578
# Total images downloaded: 579
# Total images downloaded: 580
# Total images downloaded: 581
# Total images downloaded: 582
# Total images downloaded: 583
# Total images downloaded: 584
# Total images downloaded: 585
# Total images downloaded: 586
# Total images downloaded: 587
# Total images downloaded: 588
# Total images downloaded: 589
# Total images downloaded: 590
# Total images downloaded: 591
# Total images downloaded: 592
# Total images downloaded: 593
# Total images downloaded: 594
# Total images downloaded: 595
# Total images downloaded: 596
# Total images downloaded: 597
# Total images downloaded: 598
# Total images downloaded: 599
# Total images downloaded: 600
# Sleeping for 3-5 seconds...
# Total images downloaded: 601
# Total images downloaded: 602
# Total images downloaded: 603
# Total images downloaded: 604
# Total images downloaded: 605
# Total images downloaded: 606
# Total images downloaded: 607
# Total images downloaded: 608
# Total images downloaded: 609
# Total images downloaded: 610
# Total images downloaded: 611
# Total images downloaded: 612
# Total images downloaded: 613
# Total images downloaded: 614
# Total images downloaded: 615
# Total images downloaded: 616
# Total images downloaded: 617
# Total images downloaded: 618
# Total images downloaded: 619
# Total images downloaded: 620
# Total images downloaded: 621
# Total images downloaded: 622
# Total images downloaded: 623
# Total images downloaded: 624
# Total images downloaded: 625
# Sleeping for 3-5 seconds...
# Total images downloaded: 626
# Total images downloaded: 627
# Total images downloaded: 628
# Total images downloaded: 629
# Total images downloaded: 630
# Total images downloaded: 631
# Total images downloaded: 632
# Total images downloaded: 633
# Total images downloaded: 634
# Total images downloaded: 635
# Total images downloaded: 636
# Total images downloaded: 637
# Total images downloaded: 638
# Total images downloaded: 639
# Total images downloaded: 640
# Total images downloaded: 641
# Total images downloaded: 642
# Total images downloaded: 643
# Total images downloaded: 644
# Total images downloaded: 645
# Total images downloaded: 646
# Total images downloaded: 647
# Total images downloaded: 648
# Total images downloaded: 649
# Total images downloaded: 650
# Sleeping for 3-5 seconds...
# Total images downloaded: 651
# Total images downloaded: 652
# Total images downloaded: 653
# Total images downloaded: 654
# Total images downloaded: 655
# Total images downloaded: 656
# Total images downloaded: 657
# Total images downloaded: 658
# Total images downloaded: 659
# Total images downloaded: 660
# Total images downloaded: 661
# Total images downloaded: 662
# Total images downloaded: 663
# Total images downloaded: 664
# Total images downloaded: 665
# Total images downloaded: 666
# Total images downloaded: 667
# Total images downloaded: 668
# Total images downloaded: 669
# Total images downloaded: 670
# Total images downloaded: 671
# Total images downloaded: 672
# Total images downloaded: 673
# Total images downloaded: 674
# Total images downloaded: 675
# Sleeping for 3-5 seconds...
# Total images downloaded: 676
# Total images downloaded: 677
# Total images downloaded: 678
# Total images downloaded: 679
# Total images downloaded: 680
# Total images downloaded: 681
# Total images downloaded: 682
# Total images downloaded: 683
# Total images downloaded: 684
# Total images downloaded: 685
# Total images downloaded: 686
# Total images downloaded: 687Total images downloaded: 688
#
# Total images downloaded: 689
# Total images downloaded: 690
# Total images downloaded: 691
# Total images downloaded: 692
# Total images downloaded: 693
# Total images downloaded: 694
# https://www.glamira.com/hand-of-hamsa-collection-earrings/tanzanite/
# Image Download Counts per link_category:
# Total images downloaded: 694
# Total images downloaded: 695
# Total images downloaded: 696
# Total images downloaded: 697
# Total images downloaded: 698
# Total images downloaded: 699
# Total images downloaded: 700
# Sleeping for 3-5 seconds...
# Total images downloaded: 701
# Total images downloaded: 702
# Total images downloaded: 703
# Total images downloaded: 704
# Total images downloaded: 705
# Total images downloaded: 706
# Total images downloaded: 707
# Total images downloaded: 708
# Total images downloaded: 709
# Total images downloaded: 710
# Total images downloaded: 711
# Total images downloaded: 712
# Total images downloaded: 713
# Total images downloaded: 714
# Total images downloaded: 715
# Total images downloaded: 716
# Total images downloaded: 717
# Total images downloaded: 718
# Total images downloaded: 719
# Total images downloaded: 720
# Total images downloaded: 721
# Total images downloaded: 722
# Total images downloaded: 723
# Total images downloaded: 724
# Total images downloaded: 725
# Sleeping for 3-5 seconds...
# Total images downloaded: 726
# Total images downloaded: 727
# Total images downloaded: 728
# Total images downloaded: 729
# Total images downloaded: 730
# Total images downloaded: 731
# Total images downloaded: 732
# Total images downloaded: 733
# Total images downloaded: 734
# Total images downloaded: 735
# Total images downloaded: 736
# Total images downloaded: 737
# Total images downloaded: 738
# Total images downloaded: 739
# Total images downloaded: 740
# Total images downloaded: 741
# Total images downloaded: 742
# Total images downloaded: 743
# Total images downloaded: 744
# Total images downloaded: 745
# Total images downloaded: 746
# Total images downloaded: 747
# Total images downloaded: 748
# Total images downloaded: 749
# Total images downloaded: 750
# Sleeping for 3-5 seconds...
# Total images downloaded: 751
# Total images downloaded: 752
# Total images downloaded: 753
# Total images downloaded: 754
# Total images downloaded: 755
# Total images downloaded: 756
# Total images downloaded: 757
# Total images downloaded: 758
# Total images downloaded: 759
# Total images downloaded: 760
# Total images downloaded: 761
# Total images downloaded: 762
# Total images downloaded: 763
# Total images downloaded: 764
# Total images downloaded: 765
# Total images downloaded: 766
# Total images downloaded: 767
# Total images downloaded: 768
# Total images downloaded: 769
# Total images downloaded: 770
# Total images downloaded: 771
# Total images downloaded: 772
# Total images downloaded: 773
# Total images downloaded: 774
# Total images downloaded: 775
# Sleeping for 3-5 seconds...
# Total images downloaded: 776
# Total images downloaded: 777
# Total images downloaded: 778
# Total images downloaded: 779
# Total images downloaded: 780
# Total images downloaded: 781
# Total images downloaded: 782
# Total images downloaded: 783
# Total images downloaded: 784
# Total images downloaded: 785
# Total images downloaded: 786
# Total images downloaded: 787
# Total images downloaded: 788
# Total images downloaded: 789
# Total images downloaded: 790
# Total images downloaded: 791
# Total images downloaded: 792
# Total images downloaded: 793
# Total images downloaded: 794
# Total images downloaded: 795
# Total images downloaded: 796
# Total images downloaded: 797
# Total images downloaded: 798
# Total images downloaded: 799
# Total images downloaded: 800
# Sleeping for 3-5 seconds...
# Total images downloaded: 801
# Total images downloaded: 802
# Total images downloaded: 803
# Total images downloaded: 804
# Total images downloaded: 805
# Total images downloaded: 806
# Total images downloaded: 807
# Total images downloaded: 808
# Total images downloaded: 809
# Total images downloaded: 810
# Total images downloaded: 811
# Total images downloaded: 812
# Total images downloaded: 813
# Total images downloaded: 814
# Total images downloaded: 815
# Total images downloaded: 816
# Total images downloaded: 817
# Total images downloaded: 818
# Total images downloaded: 819
# Total images downloaded: 820
# Total images downloaded: 821
# Total images downloaded: 822
# Total images downloaded: 823
# Total images downloaded: 824
# Total images downloaded: 825
# Sleeping for 3-5 seconds...
# Total images downloaded: 826
# Total images downloaded: 827
# Total images downloaded: 828
# Total images downloaded: 829
# Total images downloaded: 830
# Total images downloaded: 831
# Total images downloaded: 832
# Total images downloaded: 833
# Total images downloaded: 834
# Total images downloaded: 835
# Total images downloaded: 836
# Total images downloaded: 837
# Total images downloaded: 838
# Total images downloaded: 839
# Total images downloaded: 840
# Total images downloaded: 841
# Total images downloaded: 842
# Total images downloaded: 843
# Total images downloaded: 844
# Total images downloaded: 845
# Total images downloaded: 846
# Total images downloaded: 847
# Total images downloaded: 848
# Total images downloaded: 849
# Total images downloaded: 850
# Sleeping for 3-5 seconds...
# Total images downloaded: 851
# Total images downloaded: 852
# Total images downloaded: 853
# Total images downloaded: 854
# Total images downloaded: 855
# Total images downloaded: 856
# Total images downloaded: 857
# Total images downloaded: 858
# Total images downloaded: 859
# Total images downloaded: 860
# Total images downloaded: 861
# Total images downloaded: 862
# Total images downloaded: 863
# Total images downloaded: 864
# Total images downloaded: 865
# Total images downloaded: 866
# Total images downloaded: 867
# Total images downloaded: 868
# Total images downloaded: 869
# Total images downloaded: 870
# Total images downloaded: 871
# Total images downloaded: 872
# Total images downloaded: 873
# Total images downloaded: 874
# Total images downloaded: 875
# Sleeping for 3-5 seconds...
# Total images downloaded: 876
# Total images downloaded: 877
# Total images downloaded: 878
# Total images downloaded: 879
# Total images downloaded: 880
# Total images downloaded: 881
# Total images downloaded: 882
# Total images downloaded: 883
# Total images downloaded: 884
# Total images downloaded: 885
# Total images downloaded: 886
# Total images downloaded: 887
# Total images downloaded: 888
# Total images downloaded: 889
# Total images downloaded: 890
# Total images downloaded: 891
# Total images downloaded: 892
# Total images downloaded: 893
# Total images downloaded: 894
# Total images downloaded: 895
# Total images downloaded: 896
# Total images downloaded: 897
# Total images downloaded: 898
# Total images downloaded: 899
# Total images downloaded: 900
# Sleeping for 3-5 seconds...
# Total images downloaded: 901
# Total images downloaded: 902
# Total images downloaded: 903
# Total images downloaded: 904
# Total images downloaded: 905
# Total images downloaded: 906
# Total images downloaded: 907
# Total images downloaded: 908
# Total images downloaded: 909
# Total images downloaded: 910
# Total images downloaded: 911
# Total images downloaded: 912
# https://www.glamira.com/hand-of-hamsa-collection-earrings/blue-topaz/
# Image Download Counts per link_category:
# Total images downloaded: 912
# Total images downloaded: 913
# Total images downloaded: 914
# Total images downloaded: 915
# Total images downloaded: 916
# Total images downloaded: 917
# Total images downloaded: 918
# Total images downloaded: 919
# Total images downloaded: 920
# Total images downloaded: 921
# Total images downloaded: 922
# Total images downloaded: 923
# Total images downloaded: 924
# Total images downloaded: 925
# Sleeping for 3-5 seconds...
# Total images downloaded: 926
# Total images downloaded: 927
# Total images downloaded: 928
# Total images downloaded: 929
# Total images downloaded: 930
# Total images downloaded: 931
# Total images downloaded: 932
# Total images downloaded: 933
# Total images downloaded: 934
# Total images downloaded: 935
# Total images downloaded: 936
# Total images downloaded: 937
# Total images downloaded: 938
# Total images downloaded: 939
# Total images downloaded: 940
# Total images downloaded: 941
# Total images downloaded: 942
# Total images downloaded: 943
# Total images downloaded: 944
# Total images downloaded: 945
# Total images downloaded: 946
# Total images downloaded: 947
# Total images downloaded: 948
# Total images downloaded: 949
# Total images downloaded: 950
# Sleeping for 3-5 seconds...
# Total images downloaded: 951
# Total images downloaded: 952
# Total images downloaded: 953
# Total images downloaded: 954
# Total images downloaded: 955
# Total images downloaded: 956
# Total images downloaded: 957
# Total images downloaded: 958
# Total images downloaded: 959
# Total images downloaded: 960
# Total images downloaded: 961
# Total images downloaded: 962
# Total images downloaded: 963
# Total images downloaded: 964
# Total images downloaded: 965
# Total images downloaded: 966
# Total images downloaded: 967
# Total images downloaded: 968
# Total images downloaded: 969
# Total images downloaded: 970
# Total images downloaded: 971
# Total images downloaded: 972
# Total images downloaded: 973
# Total images downloaded: 974
# Total images downloaded: 975
# Sleeping for 3-5 seconds...
# Total images downloaded: 976
# Total images downloaded: 977
# https://www.glamira.com/hand-of-hamsa-collection-earrings/mystic-topaz/
# Image Download Counts per link_category:
# Total images downloaded: 977
# Total images downloaded: 978
# Total images downloaded: 979
# Total images downloaded: 980
# Total images downloaded: 981
# Total images downloaded: 982
# Total images downloaded: 983
# Total images downloaded: 984
# Total images downloaded: 985
# Total images downloaded: 986
# Total images downloaded: 987
# Total images downloaded: 988
# Total images downloaded: 989
# Total images downloaded: 990
# Total images downloaded: 991
# Total images downloaded: 992
# Total images downloaded: 993
# Total images downloaded: 994
# Total images downloaded: 995
# Total images downloaded: 996
# Total images downloaded: 997
# Total images downloaded: 998
# Total images downloaded: 999
# Total images downloaded: 1000
# Sleeping for 3-5 seconds...
# Total images downloaded: 1001
# Total images downloaded: 1002
# Total images downloaded: 1003
# Total images downloaded: 1004
# Total images downloaded: 1005
# Total images downloaded: 1006
# Total images downloaded: 1007
# Total images downloaded: 1008
# Total images downloaded: 1009
# Total images downloaded: 1010
# Total images downloaded: 1011
# Total images downloaded: 1012
# Total images downloaded: 1013
# Total images downloaded: 1014
# Total images downloaded: 1015
# Total images downloaded: 1016
# Total images downloaded: 1017
# Total images downloaded: 1018
# Total images downloaded: 1019
# Total images downloaded: 1020
# Total images downloaded: 1021
# Total images downloaded: 1022
# Total images downloaded: 1023
# Total images downloaded: 1024
# Total images downloaded: 1025
# Sleeping for 3-5 seconds...
# Total images downloaded: 1026
# Total images downloaded: 1027
# Total images downloaded: 1028
# Total images downloaded: 1029
# Total images downloaded: 1030
# Total images downloaded: 1031
# Total images downloaded: 1032
# Total images downloaded: 1033
# Total images downloaded: 1034
# Total images downloaded: 1035
# Total images downloaded: 1036
# Total images downloaded: 1037
# https://www.glamira.com/hand-of-hamsa-collection-earrings/pink-topaz/
# Image Download Counts per link_category:
# Total images downloaded: 1037
# Total images downloaded: 1038
# Total images downloaded: 1039
# Total images downloaded: 1040
# Total images downloaded: 1041
# Total images downloaded: 1042
# Total images downloaded: 1043
# Total images downloaded: 1044
# Total images downloaded: 1045
# Total images downloaded: 1046
# Total images downloaded: 1047
# Total images downloaded: 1048
# Total images downloaded: 1049
# Total images downloaded: 1050
# Sleeping for 3-5 seconds...
# Total images downloaded: 1051
# Total images downloaded: 1052
# Total images downloaded: 1053
# Total images downloaded: 1054
# Total images downloaded: 1055
# Total images downloaded: 1056
# Total images downloaded: 1057
# Total images downloaded: 1058
# Total images downloaded: 1059
# Total images downloaded: 1060
# Total images downloaded: 1061
# Total images downloaded: 1062
# Total images downloaded: 1063
# Total images downloaded: 1064
# Total images downloaded: 1065
# Total images downloaded: 1066
# Total images downloaded: 1067
# Total images downloaded: 1068
# Total images downloaded: 1069
# Total images downloaded: 1070
# Total images downloaded: 1071
# Total images downloaded: 1072
# Total images downloaded: 1073
# Total images downloaded: 1074
# Total images downloaded: 1075
# Sleeping for 3-5 seconds...
# Total images downloaded: 1076
# Total images downloaded: 1077
# Total images downloaded: 1078
# Total images downloaded: 1079
# Total images downloaded: 1080
# Total images downloaded: 1081
# Total images downloaded: 1082
# Total images downloaded: 1083
# Total images downloaded: 1084
# Total images downloaded: 1085
# Total images downloaded: 1086
# Total images downloaded: 1087
# Total images downloaded: 1088
# Total images downloaded: 1089
# Total images downloaded: 1090
# Total images downloaded: 1091
# Total images downloaded: 1092
# Total images downloaded: 1093
# Total images downloaded: 1094
# Total images downloaded: 1095
# https://www.glamira.com/hand-of-hamsa-collection-earrings/white-zircon/
# Image Download Counts per link_category:
# Total images downloaded: 1095
# Total images downloaded: 1096
# Total images downloaded: 1097
# Total images downloaded: 1098
# Total images downloaded: 1099
# Total images downloaded: 1100
# Sleeping for 3-5 seconds...
# Total images downloaded: 1101
# Total images downloaded: 1102
# Total images downloaded: 1103
# Total images downloaded: 1104
# Total images downloaded: 1105
# Total images downloaded: 1106
# Total images downloaded: 1107
# Total images downloaded: 1108
# Total images downloaded: 1109
# Total images downloaded: 1110
# Total images downloaded: 1111
# Total images downloaded: 1112
# Total images downloaded: 1113
# Total images downloaded: 1114
# Total images downloaded: 1115
# Total images downloaded: 1116
# Total images downloaded: 1117
# Total images downloaded: 1118
# Total images downloaded: 1119
# Total images downloaded: 1120
# Total images downloaded: 1121
# Total images downloaded: 1122
# Total images downloaded: 1123
# Total images downloaded: 1124
# Total images downloaded: 1125
# Sleeping for 3-5 seconds...
# Total images downloaded: 1126
# Total images downloaded: 1127
# Total images downloaded: 1128
# Total images downloaded: 1129
# Total images downloaded: 1130
# Total images downloaded: 1131
# Total images downloaded: 1132
# Total images downloaded: 1133
# Total images downloaded: 1134
# Total images downloaded: 1135
# Total images downloaded: 1136
# Total images downloaded: 1137
# Total images downloaded: 1138
# Total images downloaded: 1139
# Total images downloaded: 1140
# Total images downloaded: 1141
# Total images downloaded: 1142
# Total images downloaded: 1143
# Total images downloaded: 1144
# Total images downloaded: 1145
# Total images downloaded: 1146
# Total images downloaded: 1147
# Total images downloaded: 1148
# Total images downloaded: 1149
# Total images downloaded: 1150
# Sleeping for 3-5 seconds...
# Total images downloaded: 1151
# Total images downloaded: 1152
# Total images downloaded: 1153
# https://www.glamira.com/hand-of-hamsa-collection-earrings/yellow-sapphire/
# Image Download Counts per link_category:
# Total images downloaded: 1153
# Total images downloaded: 1154
# Total images downloaded: 1155
# Total images downloaded: 1156
# Total images downloaded: 1157
# Total images downloaded: 1158
# Total images downloaded: 1159
# Total images downloaded: 1160Total images downloaded: 1161
#
# Total images downloaded: 1162
# Total images downloaded: 1163
# Total images downloaded: 1164
# Total images downloaded: 1165
# Total images downloaded: 1166
# Total images downloaded: 1167
# Total images downloaded: 1168
# Total images downloaded: 1169
# Total images downloaded: 1170
# Total images downloaded: 1171
# Total images downloaded: 1172
# Total images downloaded: 1173
# Total images downloaded: 1174
# Total images downloaded: 1175
# Sleeping for 3-5 seconds...
# Total images downloaded: 1176
# Total images downloaded: 1177
# Total images downloaded: 1178
# Total images downloaded: 1179
# Total images downloaded: 1180
# Total images downloaded: 1181
# Total images downloaded: 1182
# Total images downloaded: 1183
# Total images downloaded: 1184
# Total images downloaded: 1185
# Total images downloaded: 1186
# Total images downloaded: 1187
# Total images downloaded: 1188
# Total images downloaded: 1189
# Total images downloaded: 1190
# Total images downloaded: 1191
# Total images downloaded: 1192
# Total images downloaded: 1193
# Total images downloaded: 1194
# Total images downloaded: 1195
# Total images downloaded: 1196
# Total images downloaded: 1197
# Total images downloaded: 1198
# Total images downloaded: 1199
# Total images downloaded: 1200
# Sleeping for 3-5 seconds...
# Total images downloaded: 1201
# Total images downloaded: 1202
# Total images downloaded: 1203
# Total images downloaded: 1204
# Total images downloaded: 1205
# Total images downloaded: 1206
# Total images downloaded: 1207
# Total images downloaded: 1208
# Total images downloaded: 1209
# Total images downloaded: 1210
# Total images downloaded: 1211
# Total images downloaded: 1212
# Total images downloaded: 1213
# Total images downloaded: 1214
# Total images downloaded: 1215
# Total images downloaded: 1216
# Total images downloaded: 1217
# Total images downloaded: 1218
# Total images downloaded: 1219
# Total images downloaded: 1220
# Total images downloaded: 1221
# Total images downloaded: 1222
# Total images downloaded: 1223
# Total images downloaded: 1224
# Total images downloaded: 1225
# Sleeping for 3-5 seconds...
# Total images downloaded: 1226
# Total images downloaded: 1227
# Total images downloaded: 1228
# Total images downloaded: 1229
# Total images downloaded: 1230
# Total images downloaded: 1231
# Total images downloaded: 1232
# Total images downloaded: 1233
# Total images downloaded: 1234
# Total images downloaded: 1235
# Total images downloaded: 1236
# Total images downloaded: 1237
# Total images downloaded: 1238
# Total images downloaded: 1239
# Total images downloaded: 1240
# Total images downloaded: 1241
# Total images downloaded: 1242
# Total images downloaded: 1243
# Total images downloaded: 1244
# Total images downloaded: 1245
# Total images downloaded: 1246
# Total images downloaded: 1247
# Total images downloaded: 1248
# Total images downloaded: 1249
# Total images downloaded: 1250
# Sleeping for 3-5 seconds...
# Total images downloaded: 1251
# Total images downloaded: 1252
# Total images downloaded: 1253
# Total images downloaded: 1254
# Total images downloaded: 1255
# Total images downloaded: 1256
# Total images downloaded: 1257
# Total images downloaded: 1258
# Total images downloaded: 1259
# Total images downloaded: 1260
# Total images downloaded: 1261
# Total images downloaded: 1262
# Total images downloaded: 1263
# Total images downloaded: 1264
# Total images downloaded: 1265
# Total images downloaded: 1266
# Total images downloaded: 1267
# Total images downloaded: 1268
# Total images downloaded: 1269
# Total images downloaded: 1270
# Total images downloaded: 1271
# Total images downloaded: 1272
# Total images downloaded: 1273
# Total images downloaded: 1274
# Total images downloaded: 1275
# Sleeping for 3-5 seconds...
# Total images downloaded: 1276
# Total images downloaded: 1277
# Total images downloaded: 1278
# Total images downloaded: 1279
# Total images downloaded: 1280
# Total images downloaded: 1281
# Total images downloaded: 1282
# Total images downloaded: 1283
# Total images downloaded: 1284
# Total images downloaded: 1285
# Total images downloaded: 1286
# Total images downloaded: 1287
# Total images downloaded: 1288
# Total images downloaded: 1289
# Total images downloaded: 1290
# Total images downloaded: 1291
# Total images downloaded: 1292
# Total images downloaded: 1293
# Total images downloaded: 1294
# Total images downloaded: 1295
# Total images downloaded: 1296
# Total images downloaded: 1297
# Total images downloaded: 1298
# Total images downloaded: 1299
# Total images downloaded: 1300
# Sleeping for 3-5 seconds...
# Total images downloaded: 1301
# Total images downloaded: 1302
# Total images downloaded: 1303
# Total images downloaded: 1304
# Total images downloaded: 1305
# Total images downloaded: 1306
# Total images downloaded: 1307
# Total images downloaded: 1308
# Total images downloaded: 1309
# Total images downloaded: 1310
# Total images downloaded: 1311
# Total images downloaded: 1312
# Total images downloaded: 1313
# Total images downloaded: 1314
# Total images downloaded: 1315
# Total images downloaded: 1316
# Total images downloaded: 1317
# Total images downloaded: 1318
# Total images downloaded: 1319
# Total images downloaded: 1320
# Total images downloaded: 1321
# Total images downloaded: 1322
# Total images downloaded: 1323
# Total images downloaded: 1324
# Total images downloaded: 1325
# Sleeping for 3-5 seconds...
# Total images downloaded: 1326
# Total images downloaded: 1327
# Total images downloaded: 1328
# Total images downloaded: 1329
# Total images downloaded: 1330
# Total images downloaded: 1331
# Total images downloaded: 1332
# Total images downloaded: 1333
# Total images downloaded: 1334
# Total images downloaded: 1335
# Total images downloaded: 1336
# Total images downloaded: 1337
# Total images downloaded: 1338
# Total images downloaded: 1339
# Total images downloaded: 1340Total images downloaded: 1341
#
# Total images downloaded: 1342
# Total images downloaded: 1343
# Total images downloaded: 1344
# Total images downloaded: 1345
# Total images downloaded: 1346
# Total images downloaded: 1347
# Total images downloaded: 1348
# Total images downloaded: 1349
# Total images downloaded: 1350
# Sleeping for 3-5 seconds...
# Total images downloaded: 1351
# Total images downloaded: 1352
# Total images downloaded: 1353
# Total images downloaded: 1354
# Total images downloaded: 1355
# Total images downloaded: 1356
# Total images downloaded: 1357
# Total images downloaded: 1358
# Total images downloaded: 1359
# Total images downloaded: 1360
# Total images downloaded: 1361
# Total images downloaded: 1362
# Total images downloaded: 1363
# Total images downloaded: 1364
# Total images downloaded: 1365
# Total images downloaded: 1366
# Total images downloaded: 1367
# Total images downloaded: 1368
# Total images downloaded: 1369
# Total images downloaded: 1370
# Total images downloaded: 1371
# Total images downloaded: 1372
# Total images downloaded: 1373
# Total images downloaded: 1374
# Total images downloaded: 1375
# Sleeping for 3-5 seconds...
# Total images downloaded: 1376
# Total images downloaded: 1377
# Total images downloaded: 1378
# Total images downloaded: 1379
# Total images downloaded: 1380
# Total images downloaded: 1381
# Total images downloaded: 1382
# Total images downloaded: 1383
# Total images downloaded: 1384
# Total images downloaded: 1385
# Total images downloaded: 1386
# Total images downloaded: 1387
# Total images downloaded: 1388
# Total images downloaded: 1389
# Total images downloaded: 1390
# Total images downloaded: 1391
# Total images downloaded: 1392
# Total images downloaded: 1393
# Total images downloaded: 1394
# Total images downloaded: 1395
# Total images downloaded: 1396
# Total images downloaded: 1397
# Total images downloaded: 1398
# Total images downloaded: 1399
# Total images downloaded: 1400
# Sleeping for 3-5 seconds...
# Total images downloaded: 1401
# Total images downloaded: 1402
# Total images downloaded: 1403
# Total images downloaded: 1404
# Total images downloaded: 1405
# Total images downloaded: 1406
# Total images downloaded: 1407
# Total images downloaded: 1408
# Total images downloaded: 1409
# Total images downloaded: 1410
# Total images downloaded: 1411
# Total images downloaded: 1412
# Total images downloaded: 1413
# Total images downloaded: 1414
# Total images downloaded: 1415
# Total images downloaded: 1416
# Total images downloaded: 1417
# Total images downloaded: 1418
# Total images downloaded: 1419
# Total images downloaded: 1420
# Total images downloaded: 1421
# Total images downloaded: 1422
# Total images downloaded: 1423
# Total images downloaded: 1424
# Total images downloaded: 1425
# Sleeping for 3-5 seconds...
# Total images downloaded: 1426
# Total images downloaded: 1427
# Total images downloaded: 1428
# Total images downloaded: 1429
# Total images downloaded: 1430
# Total images downloaded: 1431
# Total images downloaded: 1432
# Total images downloaded: 1433
# Total images downloaded: 1434
# Total images downloaded: 1435
# Total images downloaded: 1436
# Total images downloaded: 1437
# Total images downloaded: 1438
# Total images downloaded: 1439
# Total images downloaded: 1440Total images downloaded: 1441
#
# Total images downloaded: 1442
# Total images downloaded: 1443
# Total images downloaded: 1444
# Total images downloaded: 1445
# Total images downloaded: 1446
# Total images downloaded: 1447
# Total images downloaded: 1448
# Total images downloaded: 1449
# Total images downloaded: 1450
# Sleeping for 3-5 seconds...
# Total images downloaded: 1451
# Total images downloaded: 1452
# Total images downloaded: 1453
# Total images downloaded: 1454
# Total images downloaded: 1455
# Total images downloaded: 1456
# Total images downloaded: 1457
# Total images downloaded: 1458
# Total images downloaded: 1459
# Total images downloaded: 1460
# Total images downloaded: 1461
# Total images downloaded: 1462
# Total images downloaded: 1463
# Total images downloaded: 1464
# Total images downloaded: 1465
# Total images downloaded: 1466
# Total images downloaded: 1467
# Total images downloaded: 1468
# Total images downloaded: 1469
# Total images downloaded: 1470
# Total images downloaded: 1471
# Total images downloaded: 1472
# Total images downloaded: 1473
# Total images downloaded: 1474
# Total images downloaded: 1475
# Sleeping for 3-5 seconds...
# Total images downloaded: 1476
# Total images downloaded: 1477
# Total images downloaded: 1478
# Total images downloaded: 1479
# Total images downloaded: 1480
# Total images downloaded: 1481
# Total images downloaded: 1482
# Total images downloaded: 1483
# Total images downloaded: 1484
# Total images downloaded: 1485
# Total images downloaded: 1486
# Total images downloaded: 1487
# Total images downloaded: 1488
# Total images downloaded: 1489
# Total images downloaded: 1490
# Total images downloaded: 1491
# Total images downloaded: 1492
# Total images downloaded: 1493Total images downloaded: 1494
# Total images downloaded: 1495
#
# Total images downloaded: 1496
# Total images downloaded: 1497
# Total images downloaded: 1498
# Total images downloaded: 1499
# Total images downloaded: 1500
# Sleeping for 3-5 seconds...
# ...
# Total images downloaded: 5253
# Total images downloaded: 5254
# Total images downloaded: 5255
# Total images downloaded: 5256
# Total images downloaded: 5257
# Total images downloaded: 5258
# Total images downloaded: 5259
# Total images downloaded: 5260
# Total images downloaded: 5261
# Total images downloaded: 5262
# Total images downloaded: 5263
# Total images downloaded: 5264
# Total images downloaded: 5265
# Total images downloaded: 5266
# Total images downloaded: 5267
# Total images downloaded: 5268
# Total images downloaded: 5269
# Total images downloaded: 5270
# Total images downloaded: 5271
# Total images downloaded: 5272
# Total images downloaded: 5273
# Total images downloaded: 5274
# Total images downloaded: 5275
# Sleeping for 3-5 seconds...
# Total images downloaded: 5276
# Total images downloaded: 5277
# Total images downloaded: 5278
# Total images downloaded: 5279
# Total images downloaded: 5280
# Total images downloaded: 5281
# Total images downloaded: 5282
# Total images downloaded: 5283
# Total images downloaded: 5284
# Total images downloaded: 5285
# Total images downloaded: 5286
# Total images downloaded: 5287
# Total images downloaded: 5288
# Total images downloaded: 5289
# Total images downloaded: 5290
# Total images downloaded: 5291
# Total images downloaded: 5292
# Total images downloaded: 5293
# Total images downloaded: 5294
# Total images downloaded: 5295
# Total images downloaded: 5296
# Total images downloaded: 5297
# Total images downloaded: 5298
# Total images downloaded: 5299
# Total images downloaded: 5300
# Sleeping for 3-5 seconds...
# Total images downloaded: 5301Total images downloaded: 5302
#
# Total images downloaded: 5303
# Total images downloaded: 5304
# Total images downloaded: 5305
# Total images downloaded: 5306
# Total images downloaded: 5307
# Total images downloaded: 5308
# Total images downloaded: 5309
# Total images downloaded: 5310
# Total images downloaded: 5311
# Total images downloaded: 5312
# Total images downloaded: 5313
# https://www.glamira.com/hand-of-hamsa-collection-bracelets/princess-cut/
# Image Download Counts per link_category:
# Total images downloaded: 5313
# Total images downloaded: 5314
# Total images downloaded: 5315
# Total images downloaded: 5316
# Total images downloaded: 5317
# Total images downloaded: 5318
# Total images downloaded: 5319
# Total images downloaded: 5320
# Total images downloaded: 5321
# Total images downloaded: 5322
# Total images downloaded: 5323
# Total images downloaded: 5324
# Total images downloaded: 5325
# Sleeping for 3-5 seconds...
# Total images downloaded: 5326
# Total images downloaded: 5327
# Total images downloaded: 5328
# Total images downloaded: 5329
# Total images downloaded: 5330
# Total images downloaded: 5331
# Total images downloaded: 5332
# Total images downloaded: 5333
# Total images downloaded: 5334
# Total images downloaded: 5335
# Total images downloaded: 5336
# Total images downloaded: 5337
# Total images downloaded: 5338
# Total images downloaded: 5339
# Total images downloaded: 5340
# Total images downloaded: 5341
# Total images downloaded: 5342
# Total images downloaded: 5343
# Total images downloaded: 5344
# Total images downloaded: 5345
# Total images downloaded: 5346
# Total images downloaded: 5347
# Total images downloaded: 5348
# Total images downloaded: 5349
# Total images downloaded: 5350
# Sleeping for 3-5 seconds...
# Total images downloaded: 5351
# Total images downloaded: 5352
# Total images downloaded: 5353
# Total images downloaded: 5354
# Total images downloaded: 5355
# Total images downloaded: 5356
# Total images downloaded: 5357
# Total images downloaded: 5358
# Total images downloaded: 5359
# Total images downloaded: 5360
# Total images downloaded: 5361
# Total images downloaded: 5362
# Total images downloaded: 5363
# Total images downloaded: 5364
# Total images downloaded: 5365
# Total images downloaded: 5366
# Total images downloaded: 5367
# Total images downloaded: 5368
# Total images downloaded: 5369
# Image Download Counts per link_category:
# Total images downloaded: 5369
# Total images downloaded: 5370
# Total images downloaded: 5371
# Total images downloaded: 5372
# Total images downloaded: 5373
# Total images downloaded: 5374
# Total images downloaded: 5375
# Sleeping for 3-5 seconds...
# Total images downloaded: 5376
# Total images downloaded: 5377
# Image Download Counts per link_category:
# Total images downloaded: 5377
# Image Download Counts per link_category:
# Total images downloaded: 5377
# Total images downloaded: 5378
# Total images downloaded: 5379
# Total images downloaded: 5380
# Total images downloaded: 5381
# Total images downloaded: 5382
# Total images downloaded: 5383
# Total images downloaded: 5384
# Total images downloaded: 5385
# Total images downloaded: 5386
# Total images downloaded: 5387
# Total images downloaded: 5388
# Total images downloaded: 5389
# Total images downloaded: 5390
# Total images downloaded: 5391
# Total images downloaded: 5392
# Total images downloaded: 5393
# Total images downloaded: 5394
# Total images downloaded: 5395
# Total images downloaded: 5396
# Total images downloaded: 5397
# Total images downloaded: 5398
# Total images downloaded: 5399
# Total images downloaded: 5400
# Sleeping for 3-5 seconds...
# Total images downloaded: 5401
# Total images downloaded: 5402
# Total images downloaded: 5403
# Total images downloaded: 5404
# Total images downloaded: 5405
# Total images downloaded: 5406
# Total images downloaded: 5407
# Total images downloaded: 5408
# Image Download Counts per link_category:
# Total images downloaded: 5408
# Total images downloaded: 5409
# Total images downloaded: 5410
# Total images downloaded: 5411
# Total images downloaded: 5412
# Total images downloaded: 5413
# Total images downloaded: 5414
# Total images downloaded: 5415
# Total images downloaded: 5416
# Total images downloaded: 5417
# Total images downloaded: 5418
# Total images downloaded: 5419
# Total images downloaded: 5420
# Total images downloaded: 5421
# Total images downloaded: 5422
# Image Download Counts per link_category:
# Total images downloaded: 5422
# Total images downloaded: 5423
# Total images downloaded: 5424
# Total images downloaded: 5425
# Sleeping for 3-5 seconds...
# Total images downloaded: 5426
# Total images downloaded: 5427
# Image Download Counts per link_category:
# Total images downloaded: 5427
# Total images downloaded: 5428
# Total images downloaded: 5429
# Total images downloaded: 5430
# Total images downloaded: 5431
# Total images downloaded: 5432
# Total images downloaded: 5433
# Total images downloaded: 5434
# Total images downloaded: 5435
# Total images downloaded: 5436
# Total images downloaded: 5437
# Total images downloaded: 5438
# Total images downloaded: 5439
# Total images downloaded: 5440
# Total images downloaded: 5441
# Total images downloaded: 5442
# Total images downloaded: 5443
# Total images downloaded: 5444
# Total images downloaded: 5445
# Total images downloaded: 5446
# Total images downloaded: 5447
# Total images downloaded: 5448
# Total images downloaded: 5449Total images downloaded: 5450
# Sleeping for 3-5 seconds...
#
# Sleeping for 3-5 seconds...
# Total images downloaded: 5451
# Image Download Counts per link_category:
# Total images downloaded: 5451
# Total images downloaded: 5452
# Total images downloaded: 5453
# Total images downloaded: 5454
# Total images downloaded: 5455
# Total images downloaded: 5456
# Total images downloaded: 5457
# Total images downloaded: 5458
# Total images downloaded: 5459
# Total images downloaded: 5460
# Total images downloaded: 5461
# Total images downloaded: 5462
# Total images downloaded: 5463
# Total images downloaded: 5464
# Total images downloaded: 5465
# Total images downloaded: 5466
# Total images downloaded: 5467
# Total images downloaded: 5468
# Total images downloaded: 5469
# Total images downloaded: 5470
# Total images downloaded: 5471
# Total images downloaded: 5472
# Total images downloaded: 5473
# Total images downloaded: 5474
# Total images downloaded: 5475
# Sleeping for 3-5 seconds...
# Total images downloaded: 5476
# Total images downloaded: 5477
# Total images downloaded: 5478
# Total images downloaded: 5479
# Total images downloaded: 5480
# Total images downloaded: 5481
# Total images downloaded: 5482
# Total images downloaded: 5483
# Total images downloaded: 5484
# Total images downloaded: 5485
# Total images downloaded: 5486
# Total images downloaded: 5487
# Total images downloaded: 5488
# Total images downloaded: 5489
# Image Download Counts per link_category:
# Total images downloaded: 5489
# Total images downloaded: 5490
# Total images downloaded: 5491
# Total images downloaded: 5492
# Total images downloaded: 5493
# Total images downloaded: 5494
# Total images downloaded: 5495
# Total images downloaded: 5496
# Total images downloaded: 5497
# Total images downloaded: 5498
# Total images downloaded: 5499
# Total images downloaded: 5500
# Sleeping for 3-5 seconds...
# Total images downloaded: 5501
# Total images downloaded: 5502
# Total images downloaded: 5503
# Total images downloaded: 5504
# Total images downloaded: 5505
# Total images downloaded: 5506
# Total images downloaded: 5507
# Total images downloaded: 5508
# Total images downloaded: 5509
# Total images downloaded: 5510
# Total images downloaded: 5511
# Total images downloaded: 5512
# Total images downloaded: 5513
# Total images downloaded: 5514
# Total images downloaded: 5515
# Total images downloaded: 5516
# Total images downloaded: 5517
# Total images downloaded: 5518
# Total images downloaded: 5519
# Total images downloaded: 5520
# Total images downloaded: 5521
# Total images downloaded: 5522
# Total images downloaded: 5523
# Total images downloaded: 5524
# Total images downloaded: 5525
# Sleeping for 3-5 seconds...
# Total images downloaded: 5526
# Total images downloaded: 5527
# Total images downloaded: 5528
# Total images downloaded: 5529
# Total images downloaded: 5530
# Total images downloaded: 5531
# Total images downloaded: 5532
# Total images downloaded: 5533
# Total images downloaded: 5534
# Total images downloaded: 5535
# Total images downloaded: 5536
# Total images downloaded: 5537
# Total images downloaded: 5538
# Total images downloaded: 5539
# Total images downloaded: 5540
# Total images downloaded: 5541
# Total images downloaded: 5542
# Total images downloaded: 5543
# Total images downloaded: 5544
# Total images downloaded: 5545
# Total images downloaded: 5546
# Total images downloaded: 5547
# Total images downloaded: 5548
# Total images downloaded: 5549
# Total images downloaded: 5550
# Sleeping for 3-5 seconds...
# Total images downloaded: 5551
# Total images downloaded: 5552
# Total images downloaded: 5553
# Total images downloaded: 5554
# Total images downloaded: 5555
# Total images downloaded: 5556
# Total images downloaded: 5557
# Total images downloaded: 5558
# Total images downloaded: 5559
# Total images downloaded: 5560
# Total images downloaded: 5561
# Total images downloaded: 5562
# Total images downloaded: 5563
# Total images downloaded: 5564
# Total images downloaded: 5565
# Total images downloaded: 5566
# Total images downloaded: 5567
# Total images downloaded: 5568
# Total images downloaded: 5569
# Total images downloaded: 5570
# Total images downloaded: 5571
# Total images downloaded: 5572
# Total images downloaded: 5573
# Total images downloaded: 5574
# Total images downloaded: 5575
# Sleeping for 3-5 seconds...
# Total images downloaded: 5576
# Total images downloaded: 5577
# Total images downloaded: 5578
# Total images downloaded: 5579
# Total images downloaded: 5580
# Total images downloaded: 5581
# Total images downloaded: 5582
# Total images downloaded: 5583
# Total images downloaded: 5584
# Total images downloaded: 5585
# Total images downloaded: 5586
# Total images downloaded: 5587
# Total images downloaded: 5588
# Total images downloaded: 5589
# Total images downloaded: 5590
# Total images downloaded: 5591
# Total images downloaded: 5592
# Total images downloaded: 5593
# Total images downloaded: 5594
# Total images downloaded: 5595
# Total images downloaded: 5596
# Total images downloaded: 5597Total images downloaded: 5598
#
# Total images downloaded: 5599
# Total images downloaded: 5600
# Sleeping for 3-5 seconds...
# Total images downloaded: 5601
# Total images downloaded: 5602
# Total images downloaded: 5603
# Total images downloaded: 5604
# Total images downloaded: 5605
# Total images downloaded: 5606
# Total images downloaded: 5607
# Total images downloaded: 5608
# Total images downloaded: 5609
# Total images downloaded: 5610
# Total images downloaded: 5611
# Total images downloaded: 5612
# Total images downloaded: 5613
# Total images downloaded: 5614
# Total images downloaded: 5615
# Total images downloaded: 5616
# Total images downloaded: 5617
# Total images downloaded: 5618
# Total images downloaded: 5619Total images downloaded: 5620
#
# Total images downloaded: 5621Total images downloaded: 5622
#
# Total images downloaded: 5623
# Total images downloaded: 5624
# Total images downloaded: 5625Total images downloaded: 5626
#
# Total images downloaded: 5627
# Total images downloaded: 5628
# Total images downloaded: 5629Total images downloaded: 5630
#
# Total images downloaded: 5631
# Total images downloaded: 5632
# Total images downloaded: 5633Total images downloaded: 5634
#
# Total images downloaded: 5635Total images downloaded: 5636
#
# Total images downloaded: 5637Total images downloaded: 5638
#
# Total images downloaded: 5639
# Total images downloaded: 5640
# Total images downloaded: 5641
# Total images downloaded: 5642
# Total images downloaded: 5643
# Total images downloaded: 5644
# Total images downloaded: 5645
# Total images downloaded: 5646
# Total images downloaded: 5647
# Total images downloaded: 5648
# Total images downloaded: 5649
# Total images downloaded: 5650
# Sleeping for 3-5 seconds...
# Total images downloaded: 5651
# Total images downloaded: 5652
# Total images downloaded: 5653
# Total images downloaded: 5654
# Total images downloaded: 5655Total images downloaded: 5656
#
# Total images downloaded: 5657
# Total images downloaded: 5658
# Total images downloaded: 5659
# Total images downloaded: 5660
# Total images downloaded: 5661
# Total images downloaded: 5662
# Total images downloaded: 5663
# Total images downloaded: 5664
# Total images downloaded: 5665
# Total images downloaded: 5666
# Total images downloaded: 5667Total images downloaded: 5668
#
# Total images downloaded: 5669Total images downloaded: 5670
#
# Total images downloaded: 5671
# Total images downloaded: 5672
# Total images downloaded: 5673Total images downloaded: 5674
#
# Total images downloaded: 5675Total images downloaded: 5676
#
# Total images downloaded: 5677Total images downloaded: 5678
#
# Total images downloaded: 5679
# Total images downloaded: 5680
# Total images downloaded: 5681
# Total images downloaded: 5682
# Total images downloaded: 5683
# Total images downloaded: 5684
# Total images downloaded: 5685Total images downloaded: 5686
#
# Total images downloaded: 5687
# Total images downloaded: 5688
# Total images downloaded: 5689
# Total images downloaded: 5690
# Total images downloaded: 5691Total images downloaded: 5692
#
# Total images downloaded: 5693
# Total images downloaded: 5694
# Total images downloaded: 5695
# Total images downloaded: 5696
# Total images downloaded: 5697
# Total images downloaded: 5698
# Total images downloaded: 5699
# Total images downloaded: 5700
# Sleeping for 3-5 seconds...
# Total images downloaded: 5701
# Total images downloaded: 5702
# Total images downloaded: 5703
# Total images downloaded: 5704
# Total images downloaded: 5705
# Total images downloaded: 5706
# Total images downloaded: 5707
# Total images downloaded: 5708
# Total images downloaded: 5709
# Total images downloaded: 5710
# Total images downloaded: 5711
# Total images downloaded: 5712
# Total images downloaded: 5713
# Total images downloaded: 5714
# Total images downloaded: 5715
# Total images downloaded: 5716
# Total images downloaded: 5717
# Total images downloaded: 5718
# Total images downloaded: 5719
# Total images downloaded: 5720
# Total images downloaded: 5721
# Total images downloaded: 5722
# Total images downloaded: 5723
# Total images downloaded: 5724
# Total images downloaded: 5725
# Sleeping for 3-5 seconds...
# Total images downloaded: 5726
# Total images downloaded: 5727
# Total images downloaded: 5728
# Total images downloaded: 5729
# Total images downloaded: 5730
# Total images downloaded: 5731
# Total images downloaded: 5732
# Image Download Counts per link_category:
# Total images downloaded: 5732
# Total images downloaded: 5733
# Total images downloaded: 5734
# Total images downloaded: 5735
# Total images downloaded: 5736
# Total images downloaded: 5737
# Total images downloaded: 5738
# Total images downloaded: 5739
# Total images downloaded: 5740
# Image Download Counts per link_category:
# Total images downloaded: 5740
